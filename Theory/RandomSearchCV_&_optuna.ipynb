# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df = sns.load_dataset('iris')

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
print(df['species'].unique())
# Out:
# ['setosa' 'versicolor' 'virginica']

# %%
X = df.drop('species' , axis = 1)
y = df['species']

# %%
from sklearn.model_selection import train_test_split

# %% [markdown]
# # knn model

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=42)

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
model = KNeighborsClassifier(n_neighbors = 5)

# %%
model.fit(X_train,y_train)
# Out:
# KNeighborsClassifier()

# %%
model.score(X_test,y_test)
# Out:
# 1.0

# %% [markdown]
# # svm model

# %%
from sklearn.svm import SVC

# %%
model_svm = SVC (gamma = 'auto' )

# %%
model_svm.fit(X_train,y_train)
# Out:
# SVC(gamma='auto')

# %%
model_svm.score(X_test,y_test)
# Out:
# 1.0

# %%
from sklearn.model_selection import GridSearchCV

# %%
classifier = GridSearchCV((model_svm) ,{
    'C' : [5,10,15,20,25,30],
    'kernel' : ['linear' , 'rbf' , 'poly' , 'sigmoid']   
}, cv = 5 , return_train_score = False)

# %% [markdown]
# **When you use GridSearchCV, you don't need to manually split your data into train and test sets beforehand.**
#
# **GridSearchCV splits the data for you automatically behind the scenes.**
#
#
# **Here is how it works:**
# **It performs Cross-Validation automatically :**
# **If you look closely at the very top line of code , you can see cv=5.**
# **This tells GridSearchCV to take that plain X and y you passed in, chop it into 5 equal parts (folds), and rotate through them.**

# %%
classifier.fit(X_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=SVC(gamma='auto'),
#              param_grid={'C': [5, 10, 15, 20, 25, 30],
#                          'kernel': ['linear', 'rbf', 'poly', 'sigmoid']})

# %%
results = pd.DataFrame(classifier.cv_results_)

# %%
results.head(3)
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  param_C  \
# 0       0.001991      0.000843         0.001178        0.000198        5
# 1       0.001375      0.000102         0.000973        0.000091        5
# 2       0.002991      0.001396         0.000987        0.000073        5
#
#   param_kernel                        params  split0_test_score  \
# 0       linear  {'C': 5, 'kernel': 'linear'}           1.000000
# 1          rbf     {'C': 5, 'kernel': 'rbf'}           1.000000
# 2         poly    {'C': 5, 'kernel': 'poly'}           0.958333
#
#    split1_test_score  split2_test_score  split3_test_score  split4_test_score  \
# 0           1.000000           0.833333           1.000000           1.000000
# 1           0.958333           0.833333           1.000000           0.958333
# 2           1.000000           0.833333           0.958333           0.958333
#
#    mean_test_score  std_test_score  rank_test_score
# 0         0.966667        0.066667                1
# 1         0.950000        0.061237                3
# 2         0.941667        0.056519               10

# %%
results[['param_C','param_kernel','mean_test_score']].max()
# Out:
# param_C                  30
# param_kernel        sigmoid
# mean_test_score    0.966667
# dtype: object

# %%
X = df.drop('species' , axis = 1)
y = df['species']
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=42)

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test  = scaler.transform(X_test)

# %%
param_grid = {
    'n_neighbors': [3, 5, 7, 9],
    'weights'    : ['uniform', 'distance'],
    'metric'     : ['euclidean', 'manhattan']
}

# 5. GridSearchCV (cv=5 → 4x2x2=16 combos × 5 folds = 80 fits)
gs = GridSearchCV(
    estimator  = KNeighborsClassifier(),
    param_grid = param_grid,
    cv         = 5,
    scoring    = 'accuracy',
    n_jobs     = -1,          # use all CPU cores
    verbose    = 1
)

# %%
gs.fit(X_train, y_train)      # CV happens only inside X_train

# 6. Results
print("Best params :", gs.best_params_)
print("Best CV acc :", round(gs.best_score_, 4))

# 7. Final evaluation on the untouched test set
test_acc = gs.score(X_test, y_test)
print("Test acc    :", round(test_acc, 4))
# Out:
# Fitting 5 folds for each of 16 candidates, totalling 80 fits
# Best params : {'metric': 'euclidean', 'n_neighbors': 9, 'weights': 'distance'}
# Best CV acc : 0.9583
# Test acc    : 1.0

# %%
from sklearn.model_selection import RandomizedSearchCV

rs = RandomizedSearchCV(
    estimator           = KNeighborsClassifier(),
    param_distributions = param_grid,
    n_iter              = 20,
    cv                  = 5,
    scoring             = 'accuracy',
    random_state        = 42
)
rs.fit(X_train, y_train)
# Out:
# RandomizedSearchCV(cv=5, estimator=KNeighborsClassifier(), n_iter=20,
#                    param_distributions={'metric': ['euclidean', 'manhattan'],
#                                         'n_neighbors': [3, 5, 7, 9],
#                                         'weights': ['uniform', 'distance']},
#                    random_state=42, scoring='accuracy')

# %%
# 6. Results
print("Best params :", rs.best_params_)
print("Best CV acc :", round(rs.best_score_, 4))
# !pip install optuna
# Out:
# Best params : {'weights': 'distance', 'n_neighbors': 9, 'metric': 'euclidean'}
# Best CV acc : 0.9583
# Collecting optuna
#   Downloading optuna-4.9.0-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: alembic>=1.5.0 in /opt/anaconda3/lib/python3.13/site-packages (from optuna) (1.18.0)
# Collecting colorlog (from optuna)
#   Downloading colorlog-6.10.1-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: numpy in /opt/anaconda3/lib/python3.13/site-packages (from optuna) (2.3.5)
# Requirement already satisfied: packaging>=20.0 in /opt/anaconda3/lib/python3.13/site-packages (from optuna) (25.0)
# Requirement already satisfied: sqlalchemy>=1.4.2 in /opt/anaconda3/lib/python3.13/site-packages (from optuna) (2.0.43)
# Requirement already satisfied: tqdm in /opt/anaconda3/lib/python3.13/site-packages (from optuna) (4.67.1)
# Requirement already satisfied: PyYAML in /opt/anaconda3/lib/python3.13/site-packages (from optuna) (6.0.3)
# Requirement already satisfied: Mako in /opt/anaconda3/lib/python3.13/site-packages (from alembic>=1.5.0->optuna) (1.3.10)
# Requirement already satisfied: typing-extensions>=4.12 in /opt/anaconda3/lib/python3.13/site-packages (from alembic>=1.5.0->optuna) (4.15.0)
# Requirement already satisfied: MarkupSafe>=0.9.2 in /opt/anaconda3/lib/python3.13/site-packages (from Mako->alembic>=1.5.0->optuna) (3.0.2)
# Downloading optuna-4.9.0-py3-none-any.whl (425 kB)
# Downloading colorlog-6.10.1-py3-none-any.whl (11 kB)
# Installing collected packages: colorlog, optuna
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [optuna]━━━━ 1/2 [optuna]
# Successfully installed colorlog-6.10.1 optuna-4.9.0

# %%
import optuna
from sklearn.model_selection import cross_val_score
def objective(trial):
    n_neighbors = trial.suggest_int('n_neighbors', 3, 15)
    weights     = trial.suggest_categorical('weights', ['uniform', 'distance'])
    model = KNeighborsClassifier(n_neighbors=n_neighbors, weights=weights)
    score = cross_val_score(model, X_train, y_train, cv=5).mean()
    return score

study = optuna.create_study(direction='maximize')
study.optimize(objective, n_trials=30)
print(study.best_params)
# Out:
# [I 2026-06-13 14:48:14,305] A new study created in memory with name: no-name-aa20f7dd-d5eb-4cd8-854f-482002715ed8
# [I 2026-06-13 14:48:14,324] Trial 0 finished with value: 0.9416666666666668 and parameters: {'n_neighbors': 8, 'weights': 'uniform'}. Best is trial 0 with value: 0.9416666666666668.
# [I 2026-06-13 14:48:14,336] Trial 1 finished with value: 0.9583333333333334 and parameters: {'n_neighbors': 11, 'weights': 'distance'}. Best is trial 1 with value: 0.9583333333333334.
# [I 2026-06-13 14:48:14,349] Trial 2 finished with value: 0.9416666666666668 and parameters: {'n_neighbors': 4, 'weights': 'uniform'}. Best is trial 1 with value: 0.9583333333333334.
# [I 2026-06-13 14:48:14,361] Trial 3 finished with value: 0.9416666666666668 and parameters: {'n_neighbors': 9, 'weights': 'uniform'}. Best is trial 1 with value: 0.9583333333333334.
# [I 2026-06-13 14:48:14,377] Trial 4 finished with value: 0.9416666666666668 and parameters: {'n_neighbors': 8, 'weights': 'uniform'}. Best is trial 1 with value: 0.9583333333333334.
# [I 2026-06-13 14:48:14,387] Trial 5 finished with value: 0.9583333333333334 and parameters: {'n_neighbors': 10, 'weights': 'distance'}. Best is trial 1 with value: 0.9583333333333334.
# [I 2026-06-13 14:48:14,397] Trial 6 finished with value: 0.9583333333333334 and parameters: {'n_neighbors': 9, 'weights': 'distance'}. Best is trial 1 with value: 0.9583333333333334.
# [I 2026-06-13 14:48:14,407] Trial 7 finished with value: 0.95 and parameters: {'n_neighbors': 4, 'weights': 'distance'}. Best is trial 1 with value: 0.9583333333333334.
# [I 2026-06-13 14:48:14,416] Trial 8 finished with value: 0.95 and parameters: {'n_neighbors': 4, 'weights': 'distance'}. Best is trial 1 with value: 0.9583333333333334.
# [I 2026-06-13 14:48:14,426] Trial 9 finished with value: 0.9333333333333333 and parameters: {'n_neighbors': 6, 'weights': 'uniform'}. Best is trial 1 with value: 0.9583333333333334.
# [I 2026-06-13 14:48:14,437] Trial 10 finished with value: 0.95 and parameters: {'n_neighbors': 14, 'weights': 'distance'}. Best is trial 1 with value: 0.9583333333333334.
# [I 2026-06-13 14:48:14,446] Trial 11 finished with value: 0.95 and parameters: {'n_neighbors': 12, 'weights': 'distance'}. Best is trial 1 with value: 0.9583333333333334.
# [I 2026-06-13 14:48:14,456] Trial 12 finished with value: 0.95 and parameters: {'n_neighbors': 12, 'weights': 'distance'}. Best is trial 1 with value: 0.9583333333333334.
# [I 2026-06-13 14:48:14,467] Trial 13 finished with value: 0.9583333333333334 and parameters: {'n_neighbors': 11, 'weights': 'distance'}. Best is trial 1 with value: 0.9583333333333334.
# [I 2026-06-13 14:48:14,477] Trial 14 finished with value: 0.95 and parameters: {'n_neighbors': 15, 'weights': 'distance'}. Best is trial 1 with value: 0.9583333333333334.
# [I 2026-06-13 14:48:14,487] Trial 15 finished with value: 0.9583333333333334 and parameters: {'n_neighbors': 11, 'weights': 'distance'}. Best is trial 1 with value: 0.9583333333333334.
# [I 2026-06-13 14:48:14,498] Trial 16 finished with value: 0.95 and parameters: {'n_neighbors': 13, 'weights': 'distance'}. Best is trial 1 with value: 0.9583333333333334.
# [I 2026-06-13 14:48:14,509] Trial 17 finished with value: 0.9583333333333334 and parameters: {'n_neighbors': 10, 'weights': 'distance'}. Best is trial 1 with value: 0.9583333333333334.
# [I 2026-06-13 14:48:14,519] Trial 18 finished with value: 0.9416666666666668 and parameters: {'n_neighbors': 6, 'weights': 'distance'}. Best is trial 1 with value: 0.9583333333333334.
# [I 2026-06-13 14:48:14,530] Trial 19 finished with value: 0.95 and parameters: {'n_neighbors': 7, 'weights': 'distance'}. Best is trial 1 with value: 0.9583333333333334.
# [I 2026-06-13 14:48:14,545] Trial 20 finished with value: 0.9583333333333334 and parameters: {'n_neighbors': 10, 'weights': 'distance'}. Best is trial 1 with value: 0.9583333333333334.
# [I 2026-06-13 14:48:14,555] Trial 21 finished with value: 0.9583333333333334 and parameters: {'n_neighbors': 9, 'weights': 'distance'}. Best is trial 1 with value: 0.9583333333333334.
# [I 2026-06-13 14:48:14,565] Trial 22 finished with value: 0.9583333333333334 and parameters: {'n_neighbors': 10, 'weights': 'distance'}. Best is trial 1 with value: 0.9583333333333334.
# [I 2026-06-13 14:48:14,577] Trial 23 finished with value: 0.95 and parameters: {'n_neighbors': 12, 'weights': 'distance'}. Best is trial 1 with value: 0.9583333333333334.
# [I 2026-06-13 14:48:14,588] Trial 24 finished with value: 0.9583333333333334 and parameters: {'n_neighbors': 9, 'weights': 'distance'}. Best is trial 1 with value: 0.9583333333333334.
# [I 2026-06-13 14:48:14,602] Trial 25 finished with value: 0.9583333333333334 and parameters: {'n_neighbors': 11, 'weights': 'distance'}. Best is trial 1 with value: 0.9583333333333334.
# [I 2026-06-13 14:48:14,615] Trial 26 finished with value: 0.9416666666666668 and parameters: {'n_neighbors': 7, 'weights': 'uniform'}. Best is trial 1 with value: 0.9583333333333334.
# [I 2026-06-13 14:48:14,626] Trial 27 finished with value: 0.95 and parameters: {'n_neighbors': 13, 'weights': 'distance'}. Best is trial 1 with value: 0.9583333333333334.
# [I 2026-06-13 14:48:14,638] Trial 28 finished with value: 0.9416666666666668 and parameters: {'n_neighbors': 8, 'weights': 'distance'}. Best is trial 1 with value: 0.9583333333333334.
# [I 2026-06-13 14:48:14,651] Trial 29 finished with value: 0.9416666666666668 and parameters: {'n_neighbors': 7, 'weights': 'uniform'}. Best is trial 1 with value: 0.9583333333333334.
# {'n_neighbors': 11, 'weights': 'distance'}
